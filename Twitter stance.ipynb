# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LSTM, Bidirectional, SimpleRNN, GRU, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import gensim.downloader as api


glove_twitter = api.load("glove-twitter-100")


def text_to_glove_vector(text, model, embedding_dim):
    words = text.lower().split()
    vectors = [model[word] for word in words if word in model.key_to_index]
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(embedding_dim)
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %%
from sklearn.decomposition import PCA
def apply_glove_conversion(data, model):
    data['GloVe_Vector_Tweet'] = data['Tweet'].apply(lambda x: text_to_glove_vector(x, model, 100))
    data['GloVe_Vector_Target'] = data['Target'].apply(lambda x: text_to_glove_vector(x, model,100))
    data['Combined_Vector'] = data.apply(lambda row: np.append(row['GloVe_Vector_Tweet'], row['GloVe_Vector_Target']), axis=1)
    return data



d = pd.read_csv("/content/new_sem_eval_preprocessed.csv")
from keras.models import Sequential
d = apply_glove_conversion(d, glove_twitter)

le= LabelEncoder()
d['Stance'] = le.fit_transform(d['Stance'])

X = np.vstack(d['Combined_Vector'])
y = d['Stance']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7658)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, restore_best_weights=True)

pca = PCA(n_components=50)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

rf_classifier = RandomForestClassifier(n_estimators=500, random_state=42)
rf_classifier.fit(X_train_pca, y_train)
rf_pred = rf_classifier.predict(X_test_pca)

xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train_pca, y_train)
xgb_pred = xgb_classifier.predict(X_test_pca)


y_train_one_hot = tf.keras.utils.to_categorical(y_train)
y_test_one_hot = tf.keras.utils.to_categorical(y_test)


X_train=X_train_pca.reshape((X_train_pca.shape[0], 1, X_train_pca.shape[1]))
X_test=X_test_pca.reshape((X_test_pca.shape[0], 1, X_test_pca.shape[1]))
lstm_model = Sequential()
lstm_model.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(None, 50)))
lstm_model.add(Bidirectional(LSTM(50)))
lstm_model.add(Dense(3, activation='softmax'))
lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

lstm_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])

lstm_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
lstm_pred = np.argmax(lstm_model.predict(X_test), axis=-1)

bilstm_input = Input(shape=(None, 50))
bilstm_out = Bidirectional(LSTM(100, return_sequences=True))(bilstm_input)
bilstm_out = Bidirectional(LSTM(50))(bilstm_out)
bilstm_out = Dense(64, activation='relu')(bilstm_out)
bilstm_out = Dense(3, activation='softmax')(bilstm_out)

bilstm_model = Model(inputs=bilstm_input, outputs=bilstm_out)
bilstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

bilstm_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])

bilstm_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
bilstm_pred = np.argmax(bilstm_model.predict(X_test), axis=-1)

rnn_input = Input(shape=(None, 50))
rnn_out = SimpleRNN(100, return_sequences=True)(rnn_input)
rnn_out = SimpleRNN(50)(rnn_out)
rnn_out = Dense(64, activation='relu')(rnn_out)
rnn_out = Dense(3, activation='softmax')(rnn_out)

rnn_model = Model(inputs=rnn_input, outputs=rnn_out)
rnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

rnn_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
rnn_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
rnn_pred = np.argmax(rnn_model.predict(X_test), axis=-1)

gru_input = Input(shape=(None, 50))
gru_out = GRU(100, return_sequences=True)(gru_input)
gru_out = GRU(50)(gru_out)
gru_out = Dense(64, activation='relu')(gru_out)
gru_out = Dense(3, activation='softmax')(gru_out)

gru_model = Model(inputs=gru_input, outputs=gru_out)
gru_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

gru_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
gru_model.fit(X_train, y_train_one_hot, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
gru_pred = np.argmax(gru_model.predict(X_test), axis=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.4982 - loss: 1.0570 - val_accuracy: 0.5646 - val_loss: 0.9471 - learning_rate: 0.0010
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5837 - loss: 0.9139 - val_accuracy: 0.5600 - val_loss: 0.9017 - learning_rate: 0.0010
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6312 - loss: 0.8492 - val_accuracy: 0.5908 - val_loss: 0.8716 - learning_rate: 0.0010
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6510 - loss: 0.8133 - val_accuracy: 0.5877 - val_loss: 0.8620 - learning_rate: 0.0010
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6632 - loss: 0.7909 - val_accuracy: 0.5923 - val_loss: 0.8481 - learning_rate: 0.0010
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6438 - loss: 0.7850 - val_accuracy: 0.5892 - val_loss: 0.8549 - learning_rate: 0.0010
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6622 - loss: 0.7782 - val_accuracy: 0.6046 - val_loss: 0.8485 - learning_rate: 0.0010
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6592 - loss: 0.7551 - val_accuracy: 0.6215 - val_loss: 0.8307 - learning_rate: 0.0010
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6899 - loss: 0.7084 - val_accuracy: 0.6108 - val_loss: 0.8308 - learning_rate: 0.0010
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6730 - loss: 0.7282 - val_accuracy: 0.6169 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6862 - loss: 0.6892 - val_accuracy: 0.6262 - val_loss: 0.8259 - learning_rate: 0.0010
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7039 - loss: 0.6684 - val_accuracy: 0.6477 - val_loss: 0.8238 - learning_rate: 0.0010
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6940 - loss: 0.6880 - val_accuracy: 0.6185 - val_loss: 0.8509 - learning_rate: 0.0010
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7174 - loss: 0.6514 - val_accuracy: 0.6323 - val_loss: 0.8482 - learning_rate: 0.0010
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7197 - loss: 0.6280 - val_accuracy: 0.6400 - val_loss: 0.8476 - learning_rate: 0.0010
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7192 - loss: 0.6325 - val_accuracy: 0.6415 - val_loss: 0.8624 - learning_rate: 0.0010
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7203 - loss: 0.6329 - val_accuracy: 0.6400 - val_loss: 0.8544 - learning_rate: 0.0010
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7218 - loss: 0.6127 - val_accuracy: 0.6431 - val_loss: 0.8504 - learning_rate: 2.0000e-04
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7473 - loss: 0.5811 - val_accuracy: 0.6400 - val_loss: 0.8534 - learning_rate: 2.0000e-04
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7475 - loss: 0.5908 - val_accuracy: 0.6415 - val_loss: 0.8564 - learning_rate: 2.0000e-04
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7379 - loss: 0.5936 - val_accuracy: 0.6415 - val_loss: 0.8622 - learning_rate: 2.0000e-04
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7431 - loss: 0.5996 - val_accuracy: 0.6354 - val_loss: 0.8566 - learning_rate: 2.0000e-04
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7151 - loss: 0.6369 - val_accuracy: 0.6477 - val_loss: 0.8252 - learning_rate: 1.0000e-04
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7010 - loss: 0.6698 - val_accuracy: 0.6431 - val_loss: 0.8259 - learning_rate: 1.0000e-04
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7089 - loss: 0.6610 - val_accuracy: 0.6446 - val_loss: 0.8281 - learning_rate: 1.0000e-04
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7089 - loss: 0.6926 - val_accuracy: 0.6431 - val_loss: 0.8102 - learning_rate: 1.0000e-04
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7082 - loss: 0.6867 - val_accuracy: 0.6446 - val_loss: 0.8123 - learning_rate: 1.0000e-04
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6986 - loss: 0.6935 - val_accuracy: 0.6492 - val_loss: 0.8112 - learning_rate: 1.0000e-04
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7151 - loss: 0.6853 - val_accuracy: 0.6462 - val_loss: 0.8104 - learning_rate: 1.0000e-04
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7336 - loss: 0.6542 - val_accuracy: 0.6462 - val_loss: 0.8112 - learning_rate: 1.0000e-04
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7041 - loss: 0.6823 - val_accuracy: 0.6446 - val_loss: 0.8106 - learning_rate: 1.0000e-04
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7136 - loss: 0.6841 - val_accuracy: 0.6446 - val_loss: 0.8107 - learning_rate: 1.0000e-04
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7172 - loss: 0.6696 - val_accuracy: 0.6477 - val_loss: 0.8097 - learning_rate: 1.0000e-04
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7006 - loss: 0.6887 - val_accuracy: 0.6462 - val_loss: 0.8097 - learning_rate: 1.0000e-04
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7072 - loss: 0.6808 - val_accuracy: 0.6446 - val_loss: 0.8113 - learning_rate: 1.0000e-04
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7128 - loss: 0.6794 - val_accuracy: 0.6462 - val_loss: 0.8107 - learning_rate: 1.0000e-04
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6984 - loss: 0.6909 - val_accuracy: 0.6462 - val_loss: 0.8097 - learning_rate: 1.0000e-04
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7304 - loss: 0.6520 - val_accuracy: 0.6431 - val_loss: 0.8099 - learning_rate: 1.0000e-04
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7197 - loss: 0.6703 - val_accuracy: 0.6462 - val_loss: 0.8099 - learning_rate: 1.0000e-04
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7168 - loss: 0.6632 - val_accuracy: 0.6462 - val_loss: 0.8108 - learning_rate: 1.0000e-04
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7186 - loss: 0.6564 - val_accuracy: 0.6415 - val_loss: 0.8093 - learning_rate: 1.0000e-04
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7090 - loss: 0.6785 - val_accuracy: 0.6415 - val_loss: 0.8109 - learning_rate: 1.0000e-04
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7219 - loss: 0.6529 - val_accuracy: 0.6415 - val_loss: 0.8105 - learning_rate: 1.0000e-04
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7206 - loss: 0.6476 - val_accuracy: 0.6462 - val_loss: 0.8107 - learning_rate: 1.0000e-04
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7081 - loss: 0.6759 - val_accuracy: 0.6446 - val_loss: 0.8114 - learning_rate: 1.0000e-04
# Epoch 23/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7230 - loss: 0.6622 - val_accuracy: 0.6415 - val_loss: 0.8108 - learning_rate: 1.0000e-04
# Epoch 24/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7108 - loss: 0.6620 - val_accuracy: 0.6492 - val_loss: 0.8123 - learning_rate: 1.0000e-04
# Epoch 25/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7159 - loss: 0.6586 - val_accuracy: 0.6446 - val_loss: 0.8117 - learning_rate: 1.0000e-04
# Epoch 26/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7246 - loss: 0.6414 - val_accuracy: 0.6462 - val_loss: 0.8108 - learning_rate: 1.0000e-04
# Epoch 27/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7207 - loss: 0.6470 - val_accuracy: 0.6477 - val_loss: 0.8125 - learning_rate: 1.0000e-04
# Epoch 28/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7209 - loss: 0.6503 - val_accuracy: 0.6477 - val_loss: 0.8113 - learning_rate: 1.0000e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4992 - loss: 1.0492 - val_accuracy: 0.5615 - val_loss: 0.9522 - learning_rate: 0.0010
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5871 - loss: 0.9039 - val_accuracy: 0.5631 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6214 - loss: 0.8548 - val_accuracy: 0.5723 - val_loss: 0.8746 - learning_rate: 0.0010
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6483 - loss: 0.8110 - val_accuracy: 0.5908 - val_loss: 0.8572 - learning_rate: 0.0010
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6515 - loss: 0.8028 - val_accuracy: 0.6077 - val_loss: 0.8448 - learning_rate: 0.0010
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6617 - loss: 0.7709 - val_accuracy: 0.5892 - val_loss: 0.8453 - learning_rate: 0.0010
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6540 - loss: 0.7726 - val_accuracy: 0.6154 - val_loss: 0.8367 - learning_rate: 0.0010
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6711 - loss: 0.7296 - val_accuracy: 0.6108 - val_loss: 0.8310 - learning_rate: 0.0010
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6664 - loss: 0.7334 - val_accuracy: 0.6308 - val_loss: 0.8341 - learning_rate: 0.0010
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6771 - loss: 0.7328 - val_accuracy: 0.6277 - val_loss: 0.8367 - learning_rate: 0.0010
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5940 - loss: 0.9103 - val_accuracy: 0.5677 - val_loss: 0.9186 - learning_rate: 0.0010
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6067 - loss: 0.8760 - val_accuracy: 0.5615 - val_loss: 0.8910 - learning_rate: 0.0010
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5987 - loss: 0.8763 - val_accuracy: 0.5677 - val_loss: 0.8842 - learning_rate: 0.0010
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6333 - loss: 0.8301 - val_accuracy: 0.5800 - val_loss: 0.8663 - learning_rate: 0.0010
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6286 - loss: 0.8335 - val_accuracy: 0.5815 - val_loss: 0.8643 - learning_rate: 0.0010
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6456 - loss: 0.8081 - val_accuracy: 0.5923 - val_loss: 0.8500 - learning_rate: 0.0010
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6543 - loss: 0.7789 - val_accuracy: 0.6062 - val_loss: 0.8419 - learning_rate: 0.0010
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6600 - loss: 0.7690 - val_accuracy: 0.6108 - val_loss: 0.8392 - learning_rate: 0.0010
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6724 - loss: 0.7508 - val_accuracy: 0.6154 - val_loss: 0.8338 - learning_rate: 0.0010
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6555 - loss: 0.7504 - val_accuracy: 0.6138 - val_loss: 0.8299 - learning_rate: 0.0010
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
stacked_X_test = np.column_stack(( xgb_pred,rf_pred, lstm_pred, bilstm_pred, rnn_pred, gru_pred))

final_classifier = RandomForestClassifier(n_estimators=150, random_state=42)
final_classifier.fit(stacked_X_test, y_test)
final_pred = final_classifier.predict(stacked_X_test)

accuracy = accuracy_score(y_test, final_pred)
print(f'Combined Ensemble Accuracy: {accuracy}')
print(classification_report(y_test, final_pred, target_names=le.classes_))
# Out:
# Combined Ensemble Accuracy: 0.7109471094710947
#               precision    recall  f1-score   support
#
#      against       0.71      0.92      0.80       429
#        favor       0.72      0.56      0.63       216
#         none       0.73      0.39      0.51       168
#
#     accuracy                           0.71       813
#    macro avg       0.72      0.62      0.64       813
# weighted avg       0.71      0.71      0.69       813

# %%
majority_voting = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=1, arr=stacked_X_test)

accuracy = accuracy_score(y_test, majority_voting)

print(f'Majority Voting Accuracy: {accuracy}')
print(classification_report(y_test, majority_voting, target_names=le.classes_))
# Out:
# Majority Voting Accuracy: 0.6531365313653137
#               precision    recall  f1-score   support
#
#      against       0.68      0.86      0.76       429
#        favor       0.68      0.43      0.52       216
#         none       0.51      0.42      0.46       168
#
#     accuracy                           0.65       813
#    macro avg       0.62      0.57      0.58       813
# weighted avg       0.65      0.65      0.64       813
